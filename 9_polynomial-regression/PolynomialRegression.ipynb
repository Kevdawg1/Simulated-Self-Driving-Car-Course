# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(0)

# %%
points = 500
deviance = 0.5
X = np.linspace(-3, 3, points)
y = np.sin(X) + np.random.uniform(-deviance, deviance, points)

plt.scatter(X, y)

# %%
model = Sequential()
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))

adam = Adam(lr = 0.01)
model.compile(optimizer=adam, loss='mse')
model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 0s 585us/step - loss: 0.5421
# Epoch 2/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.2509
# Epoch 3/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.2357
# Epoch 4/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.2381
# Epoch 5/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.2219
# Epoch 6/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.2314
# Epoch 7/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.2092
# Epoch 8/50
# 500/500 [==============================] - 0s 37us/step - loss: 0.1992
# Epoch 9/50
# 500/500 [==============================] - 0s 38us/step - loss: 0.1955
# Epoch 10/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1869
# Epoch 11/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1728
# Epoch 12/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1642
# Epoch 13/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.1531
# Epoch 14/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1467
# Epoch 15/50
# 500/500 [==============================] - 0s 51us/step - loss: 0.1469
# Epoch 16/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1328
# Epoch 17/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.1228
# Epoch 18/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1195
# Epoch 19/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1174
# Epoch 20/50
# 500/500 [==============================] - 0s 48us/step - loss: 0.1143
# Epoch 21/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1127
# Epoch 22/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.1098
# Epoch 23/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1109
# Epoch 24/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1116
# Epoch 25/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1096
# Epoch 26/50
# 500/500 [==============================] - 0s 37us/step - loss: 0.1123
# Epoch 27/50
# 500/500 [==============================] - 0s 38us/step - loss: 0.1110
# Epoch 28/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1084
# Epoch 29/50
# 500/500 [==============================] - 0s 36us/step - loss: 0.1122
# Epoch 30/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1127
# Epoch 31/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1242
# Epoch 32/50
# 500/500 [==============================] - 0s 37us/step - loss: 0.1045
# Epoch 33/50
# 500/500 [==============================] - 0s 36us/step - loss: 0.1043
# Epoch 34/50
# 500/500 [==============================] - 0s 50us/step - loss: 0.1059
# Epoch 35/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1037
# Epoch 36/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.1030
# Epoch 37/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1017
# Epoch 38/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.0999
# Epoch 39/50
# 500/500 [==============================] - 0s 37us/step - loss: 0.1028
# Epoch 40/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1040
# Epoch 41/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1026
# Epoch 42/50
# 500/500 [==============================] - 0s 36us/step - loss: 0.1174
# Epoch 43/50
# 500/500 [==============================] - 0s 38us/step - loss: 0.1115
# Epoch 44/50
# 500/500 [==============================] - 0s 38us/step - loss: 0.1021
# Epoch 45/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1072
# Epoch 46/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1023
# Epoch 47/50
# 500/500 [==============================] - 0s 37us/step - loss: 0.1002
# Epoch 48/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1157
# Epoch 49/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1045
# Epoch 50/50
# 500/500 [==============================] - 0s 54us/step - loss: 0.0980

# %%
predictions = model.predict(X)
plt.scatter(X,y)
plt.plot(X, predictions, 'ro')
plt.show()
